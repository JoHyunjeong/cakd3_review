# %% [markdown]
# # 7/15

# %%
obj = """
{"name": "Wes",
 "places_lived": ["United States", "Spain", "Germany"],
 "pet": null,
 "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
              {"name": "Katie", "age": 38,
               "pets": ["Sixes", "Stache", "Cisco"]}]
}
"""

# %%
# JSON 포맷 데이터를 Python 객체로 읽기, 역직렬화, 디코딩: json.loads()
import json
result = json.loads(obj)
result
# Out:
# {'name': 'Wes',
#  'places_lived': ['United States', 'Spain', 'Germany'],
#  'pet': None,
#  'siblings': [{'name': 'Scott', 'age': 30, 'pets': ['Zeus', 'Zuko']},
#   {'name': 'Katie', 'age': 38, 'pets': ['Sixes', 'Stache', 'Cisco']}]}

# %%
# Python 객체를 JSON 데이터로 쓰기, 직렬화, 인코딩: json.dumps()
asjson = json.dumps(result)
asjson
# Out:
# '{"name": "Wes", "places_lived": ["United States", "Spain", "Germany"], "pet": null, "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]}, {"name": "Katie", "age": 38, "pets": ["Sixes", "Stache", "Cisco"]}]}'

# %%
# html을 데이터프레임으로 불러오기
import pandas as pd
tables = pd.read_html('examples/fdic_failed_bank_list.html')
len(tables)
failures = tables[0]
failures.head()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-dd0eb61c33ca> in <module>
#       1 # html을 데이터프레임으로 불러오기
#       2 import pandas as pd
# ----> 3 tables = pd.read_html('examples/fdic_failed_bank_list.html')
#       4 len(tables)
#       5 failures = tables[0]
#
# C:\anaconda3\envs\cakd3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# C:\anaconda3\envs\cakd3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1083     io = stringify_path(io)
#    1084
# -> 1085     return _parse(
#    1086         flavor=flavor,
#    1087         io=io,
#
# C:\anaconda3\envs\cakd3\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     887     retained = None
#     888     for flav in flavor:
# --> 889         parser = _parser_dispatch(flav)
#     890         p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     891
#
# C:\anaconda3\envs\cakd3\lib\site-packages\pandas\io\html.py in _parser_dispatch(flavor)
#     836     if flavor in ("bs4", "html5lib"):
#     837         if not _HAS_HTML5LIB:
# --> 838             raise ImportError("html5lib not found, please install it")
#     839         if not _HAS_BS4:
#     840             raise ImportError("BeautifulSoup4 (bs4) not found, please install it")
#
# ImportError: html5lib not found, please install it

# %%
# XML 파싱하기
from lxml import objectify

path = 'mta_perf/Performance_MNR.xml'
parsed = objectify.parse(open(path))
root = parsed.getroot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-f50e1aae0817> in <module>
#       3
#       4 path = 'dataset/mta_perf/Performance_MNR.xml'
# ----> 5 parsed = objectify.parse(open(path))
#       6 root = parsed.getroot()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset/mta_perf/Performance_MNR.xml'

# %%
data = []

skip_fields = ['PARENT_SEQ', 'INDICATOR_SEQ',
               'DESIRED_CHANGE', 'DECIMAL_PLACES']

for elt in root.INDICATOR:
    el_data = {}
    for child in elt.getchildren():
        if child.tag in skip_fields:
            continue
        el_data[child.tag] = child.pyval
    data.append(el_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e629aa83f5ba> in <module>
#       4                'DESIRED_CHANGE', 'DECIMAL_PLACES']
#       5
# ----> 6 for elt in root.INDICATOR:
#       7     el_data = {}
#       8     for child in elt.getchildren():
#
# NameError: name 'root' is not defined

# %%
perf = pd.DataFrame(data)
perf.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# 웹 API 사용하기
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp

data = resp.json()
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45187',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45187/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45187/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45187/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/45187',
#   'id': 1093169100,
#   'node_id': 'I_kwDOAA0YD85BKG_M',
#   'number': 45187,
#   'title': 'BUG:  groupby apply on single group transposes series output',
#   'user': {'login': 'seanv507',
#    'id': 3305775,
#    'node_id': 'MDQ6VXNlcjMzMDU3NzU=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3305775?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/seanv507',
#    'html_url': 'https://github.com/seanv507',
#    'followers_url': 'https://api.github.com/users/seanv507/followers',
#    'following_url': 'https://api.github.com/users/seanv507/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/seanv507/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/seanv507/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/seanv507/subscriptions',
#    'organizations_url': 'https://api.github.com/users/seanv507/orgs',
#    'repos_url': 'https://api.github.com/users/seanv507/repos',
#    'events_url': 'https://api.github.com/users/seanv507/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/seanv507/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-01-04T09:34:54Z',
#   'updated_at': '2022-01-04T09:34:54Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the master branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\ndf = pd.DataFrame({\'A\': \'a a\'.split(),\r\n                   \'B\': [1,2],\r\n                   \'C\': [4,6]})\r\ndf.groupby("A").apply(lambda x: x["C"]>x["B"])\r\n\r\n# output\r\n#       0     1\r\n# A            \r\n# a  True  True\r\n# dtype: bool\r\ndf2 = pd.DataFrame({\'A\': \'a a b b\'.split(),\r\n                    \'B\': [1,2, 3, 4],\r\n                    \'C\': [5,6, 7, 8],\r\n                    \'D\': [5,6, 7, 8]\r\n}\r\n)\r\n\r\ndf2.groupby("A").apply(lambda x: x["C"]>x["B"])\r\n# output \r\n# A   \r\n# a  0    True\r\n#    1    True\r\n# b  2    True\r\n#    3    True\r\n# dtype: bool\n```\n\n\n### Issue Description\n\nthe apply function is returning a series. if a single group is output the series is treated as a row vector, if multiple groups it is returned as a column vector as expected.\r\n\r\n\n\n### Expected Behavior\n\ndf.groupby("A").apply(lambda x: x["C"]>x["B"])\r\n# output \r\n# A   \r\n# a  0    True\r\n#     1    True\n\n### Installed Versions\n\n<details>\r\n\r\npython 3.10.1\r\npandas 1.3.5\r\n\r\nshow versions crashed (created by running conda create -n test_pandas pandas on Mac OSX)\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45187/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45187/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45186',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45186/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45186/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45186/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/45186',
#   'id': 1092988511,
#   'node_id': 'PR_kwDOAA0YD84wfcXb',
#   'number': 45186,
#   'title': 'DEPR: inplace setting of Categorical.categories',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-01-04T03:57:53Z',
#   'updated_at': '2022-01-04T03:58:38Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/45186',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/45186',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/45186.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/45186.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx\r\n- [x] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [x] whatsnew entry\r\n\r\nI thought we had gotten all of these, but apparently not.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45186/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45186/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45185',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45185/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45185/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45185/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/45185',
#   'id': 1092944485,
#   'node_id': 'PR_kwDOAA0YD84wfTuJ',
#   'number': 45185,
#   'title': 'TST: Create test for #30122 about display.precision',
#   'user': {'login': 'dhruvsamdani',
#    'id': 25727722,
#    'node_id': 'MDQ6VXNlcjI1NzI3NzIy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25727722?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dhruvsamdani',
#    'html_url': 'https://github.com/dhruvsamdani',
#    'followers_url': 'https://api.github.com/users/dhruvsamdani/followers',
#    'following_url': 'https://api.github.com/users/dhruvsamdani/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/dhruvsamdani/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/dhruvsamdani/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/dhruvsamdani/subscriptions',
#    'organizations_url': 'https://api.github.com/users/dhruvsamdani/orgs',
#    'repos_url': 'https://api.github.com/users/dhruvsamdani/repos',
#    'events_url': 'https://api.github.com/users/dhruvsamdani/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/dhruvsamdani/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-01-04T01:55:17Z',
#   'updated_at': '2022-01-04T01:55:43Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/45185',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/45185',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/45185.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/45185.patch',
#    'merged_at': None},
#   'body': '- [x] closes #30122 \r\n- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [ ] whatsnew entry\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45185/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45185/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45184',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45184/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45184/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45184/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/45184',
#   'id': 1092924913,
#   'node_id': 'PR_kwDOAA0YD84wfP5M',
#   'number': 45184,
#   'title': 'CLN: assorted follow-ups',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-01-04T00:56:56Z',
#   'updated_at': '2022-01-04T00:56:56Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/45184',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/45184',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/45184.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/45184.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx\r\n- [ ] tests added / passed\r\n- [ ] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [ ] whatsnew entry\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45184/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45184/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45183',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45183/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45183/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45183/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/45183',
#   'id': 1092921567,
#   'node_id': 'PR_kwDOAA0YD84wfPPV',
#   'number': 45183,
#   'title': 'TST: parameterize and split',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-01-04T00:45:42Z',
#   'updated_at': '2022-01-04T00:45:42Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/45183',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/45183',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/45183.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/45183.patch',
#    'merged_at': None},
#   'body': '- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45183/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45183/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45182',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45182/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45182/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45182/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/45182',
#   'id': 1092909648,
#   'node_id': 'I_kwDOAA0YD85BJHpQ',
#   'number': 45182,
#   'title': 'CI: Numpy 1.22 caused CI to fail',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Continuous Integration'},
#    {'id': 77550281,
#     'node_id': 'MDU6TGFiZWw3NzU1MDI4MQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Blocker',
#     'name': 'Blocker',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Blocking issue or pull request for an upcoming release'},
#    {'id': 527603109,
#     'node_id': 'MDU6TGFiZWw1Mjc2MDMxMDk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dependencies',
#     'name': 'Dependencies',
#     'color': 'd93f0b',
#     'default': False,
#     'description': 'Required and optional dependencies'},
#    {'id': 1280988427,
#     'node_id': 'MDU6TGFiZWwxMjgwOTg4NDI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Typing',
#     'name': 'Typing',
#     'color': 'ea91a4',
#     'default': False,
#     'description': 'type annotations, mypy/pyright type checking'},
#    {'id': 2138993554,
#     'node_id': 'MDU6TGFiZWwyMTM4OTkzNTU0',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/numba',
#     'name': 'numba',
#     'color': '5319e7',
#     'default': False,
#     'description': 'numba-accelerated operations'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/86',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/86',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/86/labels',
#    'id': 6840253,
#    'node_id': 'MDk6TWlsZXN0b25lNjg0MDI1Mw==',
#    'number': 86,
#    'title': '1.4',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 45,
#    'closed_issues': 1754,
#    'state': 'open',
#    'created_at': '2021-06-09T18:28:42Z',
#    'updated_at': '2022-01-04T10:47:10Z',
#    'due_on': '2021-12-31T08:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2022-01-04T00:12:46Z',
#   'updated_at': '2022-01-04T10:47:33Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': 'The test\r\n\r\n```\r\nFAILED pandas/tests/frame/test_ufunc.py::test_alignment_deprecation_many_inputs\r\n```\r\n\r\nis failing.\r\n\r\nAlso we have some typing problems\r\n\r\n\r\n```\r\nPerforming static analysis using mypy\r\npandas/core/internals/ops.py:130: error: Unused "type: ignore" comment\r\npandas/core/dtypes/common.py:539: error: Unused "type: ignore" comment\r\npandas/core/dtypes/cast.py:1127: error: Unused "type: ignore" comment\r\npandas/core/dtypes/cast.py:1149: error: Unused "type: ignore" comment\r\npandas/core/missing.py:337: error: Argument 1 to "apply_along_axis" has incompatible type "Callable[[ndarray[Any, Any]], None]"; expected "Callable[..., Union[_SupportsArray[dtype[<nothing>]], Sequence[_SupportsArray[dtype[<nothing>]]], Sequence[Sequence[_SupportsArray[dtype[<nothing>]]]], Sequence[Sequence[Sequence[_SupportsArray[dtype[<nothing>]]]]], Sequence[Sequence[Sequence[Sequence[_SupportsArray[dtype[<nothing>]]]]]]]]"  [arg-type]\r\npandas/core/missing.py:776: error: Argument 1 to "apply_along_axis" has incompatible type "partial[None]"; expected "Callable[..., Union[_SupportsArray[dtype[<nothing>]], Sequence[_SupportsArray[dtype[<nothing>]]], Sequence[Sequence[_SupportsArray[dtype[<nothing>]]]], Sequence[Sequence[Sequence[_SupportsArray[dtype[<nothing>]]]]], Sequence[Sequence[Sequence[Sequence[_SupportsArray[dtype[<nothing>]]]]]]]]"  [arg-type]\r\npandas/core/missing.py:776: note: "partial[None].__call__" has type "Callable[[VarArg(Any), KwArg(Any)], None]"\r\npandas/core/missing.py:782: error: Argument 2 to "apply_along_axis" has incompatible type "Union[str, int]"; expected "SupportsIndex"  [arg-type]\r\npandas/core/arraylike.py:271: error: Unused "type: ignore" comment\r\npandas/core/algorithms.py:772: error: Argument 2 to "append" has incompatible type "List[Union[str, float, Period, Timestamp, Timedelta, Any]]"; expected "Union[_SupportsArray[dtype[Any]], _NestedSequence[_SupportsArray[dtype[Any]]], bool, int, float, complex, str, bytes, _NestedSequence[Union[bool, int, float, complex, str, bytes]]]"  [arg-type]\r\npandas/core/algorithms.py:1071: error: Argument 1 to "__call__" of "_UFunc_Nin1_Nout1" has incompatible type "Optional[ndarray[Any, dtype[bool_]]]"; expected "Union[_SupportsArray[dtype[Any]], _NestedSequence[_SupportsArray[dtype[Any]]], bool, int, float, complex, str, bytes, _NestedSequence[Union[bool, int, float, complex, str, bytes]]]"  [arg-type]\r\npandas/core/strings/accessor.py:585: error: Incompatible types in assignment (expression has type "ndarray[Any, dtype[Any]]", variable has type "Series")  [assignment]\r\npandas/core/indexes/base.py:611: error: Unused "type: ignore" comment\r\npandas/core/indexes/base.py:4527: error: Argument 3 to "putmask" has incompatible type "Union[ExtensionArray, ndarray[Any, Any]]"; expected "Union[_SupportsArray[dtype[Any]], _NestedSequence[_SupportsArray[dtype[Any]]], bool, int, float, complex, str, bytes, _NestedSequence[Union[bool, int, float, complex, str, bytes]]]"  [arg-type]\r\npandas/core/indexes/base.py:5029: error: Item "ExtensionArray" of "Union[ExtensionArray, ndarray[Any, Any]]" has no attribute "_ndarray"  [union-attr]\r\npandas/core/indexes/base.py:5029: error: Item "ndarray[Any, Any]" of "Union[ExtensionArray, ndarray[Any, Any]]" has no attribute "_ndarray"  [union-attr]\r\npandas/core/indexes/base.py:6520: error: Incompatible types in assignment (expression has type "ExtensionArray", variable has type "ndarray[Any, dtype[Any]]")  [assignment]\r\npandas/core/indexes/base.py:6571: error: No overload variant of "insert" matches argument types "ndarray[Any, Any]", "int", "None"  [call-overload]\r\npandas/core/indexes/base.py:6571: note: Possible overload variants:\r\npandas/core/indexes/base.py:6571: note:     def [_SCT <: generic] insert(arr: Union[_SupportsArray[dtype[_SCT]], Sequence[_SupportsArray[dtype[_SCT]]], Sequence[Sequence[_SupportsArray[dtype[_SCT]]]], Sequence[Sequence[Sequence[_SupportsArray[dtype[_SCT]]]]], Seq ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45182/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45182/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45181',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45181/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45181/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45181/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/45181',
#   'id': 1092893000,
#   'node_id': 'PR_kwDOAA0YD84wfJhm',
#   'number': 45181,
#   'title': 'BUG: Index.get_loc always raise InvalidIndexError on listlike',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2822098,
#     'node_id': 'MDU6TGFiZWwyODIyMDk4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Indexing',
#     'name': 'Indexing',
#     'color': '0b02e1',
#     'default': False,
#     'description': 'Related to indexing on series/frames, not to indexes themselves'},
#    {'id': 42670965,
#     'node_id': 'MDU6TGFiZWw0MjY3MDk2NQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Error%20Reporting',
#     'name': 'Error Reporting',
#     'color': 'ffa0ff',
#     'default': False,
#     'description': 'Incorrect or improved errors from pandas'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2022-01-03T23:27:02Z',
#   'updated_at': '2022-01-04T00:27:50Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/45181',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/45181',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/45181.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/45181.patch',
#    'merged_at': None},
#   'body': "- [ ] closes #xxxx\r\n- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [ ] whatsnew entry\r\n\r\nShouldn't be user-facing unless user is using Index.get_loc directly since we catch this in the relevant Series/DataFrame indexing methods.  The upshot here is this will allow us to simplify `Series.__setitem__` (and maybe others)",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45181/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45181/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45180',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45180/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45180/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45180/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/45180',
#   'id': 1092875145,
#   'node_id': 'PR_kwDOAA0YD84wfFsu',
#   'number': 45180,
#   'title': 'BUG: encoding_errors=None with read_csv c-engine',
#   'user': {'login': 'twoertwein',
#    'id': 6618166,
#    'node_id': 'MDQ6VXNlcjY2MTgxNjY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6618166?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/twoertwein',
#    'html_url': 'https://github.com/twoertwein',
#    'followers_url': 'https://api.github.com/users/twoertwein/followers',
#    'following_url': 'https://api.github.com/users/twoertwein/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/twoertwein/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/twoertwein/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/twoertwein/subscriptions',
#    'organizations_url': 'https://api.github.com/users/twoertwein/orgs',
#    'repos_url': 'https://api.github.com/users/twoertwein/repos',
#    'events_url': 'https://api.github.com/users/twoertwein/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/twoertwein/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 47229171,
#     'node_id': 'MDU6TGFiZWw0NzIyOTE3MQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20CSV',
#     'name': 'IO CSV',
#     'color': '5319e7',
#     'default': False,
#     'description': 'read_csv, to_csv'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2022-01-03T22:52:03Z',
#   'updated_at': '2022-01-04T04:32:17Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/45180',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/45180',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/45180.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/45180.patch',
#    'merged_at': None},
#   'body': "The c-engine did not handle `encoding_errors=None`.\r\n\r\nThe test case for `replace` was simply wrong in case of read_csv.\r\n\r\nUn-blocks @MarcoGorelli's #45173.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45180/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45180/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45178',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45178/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45178/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45178/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/45178',
#   'id': 1092821729,
#   'node_id': 'I_kwDOAA0YD85BIyLh',
#   'number': 45178,
#   'title': 'CI: dev requirements version inconsistencies',
#   'user': {'login': 'attack68',
#    'id': 24256554,
#    'node_id': 'MDQ6VXNlcjI0MjU2NTU0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24256554?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/attack68',
#    'html_url': 'https://github.com/attack68',
#    'followers_url': 'https://api.github.com/users/attack68/followers',
#    'following_url': 'https://api.github.com/users/attack68/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/attack68/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/attack68/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/attack68/subscriptions',
#    'organizations_url': 'https://api.github.com/users/attack68/orgs',
#    'repos_url': 'https://api.github.com/users/attack68/repos',
#    'events_url': 'https://api.github.com/users/attack68/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/attack68/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Continuous Integration'},
#    {'id': 527603109,
#     'node_id': 'MDU6TGFiZWw1Mjc2MDMxMDk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dependencies',
#     'name': 'Dependencies',
#     'color': 'd93f0b',
#     'default': False,
#     'description': 'Required and optional dependencies'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2022-01-03T21:10:24Z',
#   'updated_at': '2022-01-03T22:02:37Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the master branch of pandas.\n\n\n### Reproducible Example\n\n```python\n..\n```\n\n\n### Issue Description\n\nHaving difficulty replicating the ci checks locally so trying to install a new environment. My package resolver doesn't work. Trying to debug I have:\r\n\r\n```\r\n>>> pip-compile requirements-dev.in  (converted from .txt)\r\nThere are incompatible versions in the resolved dependencies:\r\n  aiobotocore<2.0.0 (from -r requirements-dev2.in (line 77))\r\n  aiobotocore~=2.0.1 (from s3fs==2021.11.1->-r requirements-dev2.in (line 76))\r\n```\r\n\r\nOK so I lower my version of s3fs to `s3fs<2021.11.1`\r\n\r\n```\r\n>>> pip-compile requirements-dev.in  (converted from .txt)\r\nThere are incompatible versions in the resolved dependencies:\r\n  botocore>=1.11 (from -r requirements-dev2.in (line 40))\r\n  botocore<1.24.0,>=1.23.27 (from boto3==1.20.27->-r requirements-dev2.in (line 39))\r\n  botocore<1.20.107,>=1.20.106 (from aiobotocore==1.4.2->-r requirements-dev2.in (line 77))\r\n  botocore>=1.12.201 (from moto==2.3.0->-r requirements-dev2.in (line 42))\r\n```\r\n\r\nOK so now I lower boto3 to `boto3<1.17.1`:\r\n\r\n```\r\n>>> pip-compile ...\r\nThere are incompatible versions in the resolved dependencies:\r\n  fsspec>=0.7.4 (from -r requirements-dev2.in (line 78))\r\n  fsspec (from fastparquet==0.7.2->-r requirements-dev2.in (line 72))\r\n  fsspec>=0.6.0 (from dask==2021.12.0->-r requirements-dev2.in (line 31))\r\n  fsspec==2021.11.0 (from s3fs==2021.11.0->-r requirements-dev2.in (line 76))\r\n  fsspec==2021.11.1 (from gcsfs==2021.11.1->-r requirements-dev2.in (line 79))\r\n```\r\n\r\nAnd finally I lower gcsfs to `gcsfs==2021.11.0`.\r\n\r\nAnd it resolves!\r\n\r\nI wonder if it is worth using a package compiler to avoid these issues now that many packages are in the development requirements and haven't been specifically pinned? Then at least everyone can be on the same environment?\r\n\r\nI also have a suspicion that `numpy==1.20.3` is not sufficient to run the `mypy` typing checks since I get a `npt` error. With 1.21 installed I don't get this error.\r\n\r\n```\r\n#\r\n# This file is autogenerated by pip-compile with python 3.9\r\n# To update, run:\r\n#\r\n#    pip-compile requirements-dev2.in\r\n#\r\naiobotocore==1.4.2\r\n    # via\r\n    #   -r requirements-dev2.in\r\n    #   s3fs\r\naiohttp==3.8.1\r\n    # via\r\n    #   aiobotocore\r\n    #   gcsfs\r\n    #   s3fs\r\naioitertools==0.8.0\r\n    # via aiobotocore\r\naiosignal==1.2.0\r\n    # via aiohttp\r\nalabaster==0.7.12\r\n    # via sphinx\r\nappdirs==1.4.4\r\n    # via black\r\nappnope==0.1.2\r\n    # via\r\n    #   ipykernel\r\n    #   ipython\r\nargon2-cffi==21.3.0\r\n    # via notebook\r\nargon2-cffi-bindings==21.2.0\r\n    # via argon2-cffi\r\nasv==0.4.2\r\n    # via -r requirements-dev2.in\r\nasync-timeout==4.0.2\r\n    # via aiohttp\r\nattrs==21.4.0\r\n    # via\r\n    #   aiohttp\r\n    #   flake8-bugbear\r\n    #   hypothesis\r\n    #   jsonschema\r\n    #   pytest\r\nbabel==2.9.1\r\n    # via sphinx\r\nbackcall==0.2.0\r\n    # via ipython\r\nbeautifulsoup4==4.10.0\r\n    # via -r requirements-dev2.in\r\nblack==21.5b2\r\n    # via -r requirements-dev2.in\r\nbleach==4.1.0\r\n    # via nbconvert\r\nblosc==1.10.6\r\n    # via -r requirements-dev2.in\r\nboto3==1.17.0\r\n    # via\r\n    #   -r requirements-dev2.in\r\n    #   moto\r\nbotocore==1.20.106\r\n    # via\r\n    #   -r requirements-dev2.in\r\n    #   aiobotocore\r\n    #   boto3\r\n    #   moto\r\n    #   s3transfer\r\nbottleneck==1.3.2\r\n    # via -r requirements-dev2.in\r\ncachetools==4.2.4\r\n    # via google-auth\r\ncertifi==2021.10.8\r\n    # via requests\r\ncffi==1.15.0\r\n    # via\r\n    #   argon2-cffi-bindings\r\n   ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45178/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45178/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45177',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45177/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45177/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45177/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/45177',
#   'id': 1092768726,
#   'node_id': 'I_kwDOAA0YD85BIlPW',
#   'number': 45177,
#   'title': 'BUG: `DataFrame.to_string()` - customer formatter ***not*** called for all values in column',
#   'user': {'login': 'DanielGoldfarb',
#    'id': 11164790,
#    'node_id': 'MDQ6VXNlcjExMTY0Nzkw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11164790?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DanielGoldfarb',
#    'html_url': 'https://github.com/DanielGoldfarb',
#    'followers_url': 'https://api.github.com/users/DanielGoldfarb/followers',
#    'following_url': 'https://api.github.com/users/DanielGoldfarb/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/DanielGoldfarb/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/DanielGoldfarb/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/DanielGoldfarb/subscriptions',
#    'organizations_url': 'https://api.github.com/users/DanielGoldfarb/orgs',
#    'repos_url': 'https://api.github.com/users/DanielGoldfarb/repos',
#    'events_url': 'https://api.github.com/users/DanielGoldfarb/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/DanielGoldfarb/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 4,
#   'created_at': '2022-01-03T19:42:28Z',
#   'updated_at': '2022-01-04T00:16:31Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the master branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\nimport datetime\r\n\r\nprint(\'==============================\')\r\nprint(\'pd.__version__=\',pd.__version__)\r\n\r\nmylist = [\'abcd\',123,None,456.78,float(\'nan\'),\'wxyz\',1234567,\' \',datetime.datetime.now(),-321,None,3.1415926536]\r\n\r\ndf = pd.DataFrame(dict(MyColumn=mylist))\r\n\r\nprint(\'==============================\')\r\nprint(df)\r\nprint(\'==============================\')\r\n\r\ndef myformatter(value):\r\n    print(\'type(value)=\',type(value),\' value=\',value)\r\n    #return f\'{value:<10}\'\r\n    return \'%-10.10s\' % value\r\n\r\nf = {\'MyColumn\': myformatter}\r\n\r\ns = df.to_string(formatters=f,float_format=myformatter,na_rep=\'na_rep\',\r\n                 index=False,justify=\'left\')\r\n\r\nprint(\'==============================\')\r\nprint(s)\r\nprint(\'==============================\')\n```\n\n\n### Issue Description\n\nPer Pandas documentation for [**`DataFrame.to_string`**](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_string.html), the `formatters` parameter is a \r\n> list, tuple, or dict of one-parameter functions ... Formatter functions to apply to columns’ elements by position or name.\r\n\r\n**note:** "apply to columns’ elements" (it does not say "apply to *only some* elements")\r\n\r\nThe "Reproducible example" code demonstrates that the formatter is *not* called for all elements in the column.  See output below.  \r\n\r\nSpecifically it appears that customer formatters are not called for the following types: `float`, `NoneType`, and `NaN`.  This is not a big deal for `float` because the  parameter `float_format` allows one to install a formatter function for floats as well.  However ***this prevents the user from custom formatting `NoneType` and `NaN` with their formatting function.***\r\n\r\nIn the reproducible example given, the user has chosen to format the column as left justified, however because `None` and `NaN` values are not passed to the customer formatter, the user is unable to accomplish this task.\r\n\r\nHere is the output from the above reproducible example:\r\n```text\r\n==============================\r\npd.__version__= 1.3.5\r\n==============================\r\n                      MyColumn\r\n0                         abcd\r\n1                          123\r\n2                         None\r\n3                       456.78\r\n4                          NaN\r\n5                         wxyz\r\n6                      1234567\r\n7\r\n8   2022-01-03 14:37:24.075486\r\n9                         -321\r\n10                        None\r\n11                    3.141593\r\n==============================\r\ntype(value)= <class \'str\'>  value= abcd\r\ntype(value)= <class \'int\'>  value= 123\r\ntype(value)= <class \'float\'>  value= 456.78\r\ntype(value)= <class \'str\'>  value= wxyz\r\ntype(value)= <class \'int\'>  value= 1234567\r\ntype(value)= <class \'str\'>  value=\r\ntype(value)= <class \'datetime.datetime\'>  value= 2022-01-03 14:37:24.075486\r\ntype(value)= <class \'int\'>  value= -321\r\ntype(value)= <class \'float\'>  value= 3.1415926536\r\n==============================\r\nMyColumn\r\nabcd\r\n123\r\n      None\r\n456.78\r\n    na_rep\r\nwxyz\r\n1234567\r\n\r\n2022-01-03\r\n-321\r\n      None\r\n3.14159265\r\n==============================\r\n```\r\n\n\n### Expected Behavior\n\n**Custom formatter functions should be called *for all elements in the specified column.***\r\n\r\nSince installation of custom formatters is already split between two paramters (`formatters` and `float_format`) it may be reasonable to pass `NoneType` to the `formatters` and `NaN` to the `float_format` form ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45177/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45177/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45176',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45176/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45176/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45176/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/45176',
#   'id': 1092672170,
#   'node_id': 'PR_kwDOAA0YD84webeH',
#   'number': 45176,
#   'title': 'ENH: `Styler.show` shorthand alternative to `hide`',
#   'user': {'login': 'attack68',
#    'id': 24256554,
#    'node_id': 'MDQ6VXNlcjI0MjU2NTU0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24256554?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/attack68',
#    'html_url': 'https://github.com/attack68',
#    'followers_url': 'https://api.github.com/users/attack68/followers',
#    'following_url': 'https://api.github.com/users/attack68/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/attack68/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/attack68/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/attack68/subscriptions',
#    'organizations_url': 'https://api.github.com/users/attack68/orgs',
#    'repos_url': 'https://api.github.com/users/attack68/repos',
#    'events_url': 'https://api.github.com/users/attack68/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/attack68/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1728592794,
#     'node_id': 'MDU6TGFiZWwxNzI4NTkyNzk0',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Styler',
#     'name': 'Styler',
#     'color': '006b75',
#     'default': False,
#     'description': 'conditional formatting using DataFrame.style'}],
# ...
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 47229171,
#     'node_id': 'MDU6TGFiZWw0NzIyOTE3MQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20CSV',
#     'name': 'IO CSV',
#     'color': '5319e7',
#     'default': False,
#     'description': 'read_csv, to_csv'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/86',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/86',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/86/labels',
#    'id': 6840253,
#    'node_id': 'MDk6TWlsZXN0b25lNjg0MDI1Mw==',
#    'number': 86,
#    'title': '1.4',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 45,
#    'closed_issues': 1754,
#    'state': 'open',
#    'created_at': '2021-06-09T18:28:42Z',
#    'updated_at': '2022-01-04T10:47:10Z',
#    'due_on': '2021-12-31T08:00:00Z',
#    'closed_at': None},
#   'comments': 4,
#   'created_at': '2021-12-31T23:27:27Z',
#   'updated_at': '2022-01-03T23:39:11Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/45146',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/45146',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/45146.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/45146.patch',
#    'merged_at': None},
#   'body': '- [x] closes #5686\r\n- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [x] whatsnew entry\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45146/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45146/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45145',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45145/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45145/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45145/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/45145',
#   'id': 1091682819,
#   'node_id': 'PR_kwDOAA0YD84wbTCe',
#   'number': 45145,
#   'title': 'BUG: Fix for xlabel/ylabel in barh plot',
#   'user': {'login': 'stefmolin',
#    'id': 24376333,
#    'node_id': 'MDQ6VXNlcjI0Mzc2MzMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24376333?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/stefmolin',
#    'html_url': 'https://github.com/stefmolin',
#    'followers_url': 'https://api.github.com/users/stefmolin/followers',
#    'following_url': 'https://api.github.com/users/stefmolin/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/stefmolin/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/stefmolin/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/stefmolin/subscriptions',
#    'organizations_url': 'https://api.github.com/users/stefmolin/orgs',
#    'repos_url': 'https://api.github.com/users/stefmolin/repos',
#    'events_url': 'https://api.github.com/users/stefmolin/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/stefmolin/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-12-31T22:51:46Z',
#   'updated_at': '2021-12-31T23:34:21Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/45145',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/45145',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/45145.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/45145.patch',
#    'merged_at': None},
#   'body': '- [X] closes #45144\r\n- [X] tests added / passed\r\n- [X] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [X] whatsnew entry\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45145/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45145/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45144',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45144/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45144/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45144/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/45144',
#   'id': 1091681669,
#   'node_id': 'I_kwDOAA0YD85BEb2F',
#   'number': 45144,
#   'title': "BUG: xlabel/ylabel don't work as expected with barh plots",
#   'user': {'login': 'stefmolin',
#    'id': 24376333,
#    'node_id': 'MDQ6VXNlcjI0Mzc2MzMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24376333?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/stefmolin',
#    'html_url': 'https://github.com/stefmolin',
#    'followers_url': 'https://api.github.com/users/stefmolin/followers',
#    'following_url': 'https://api.github.com/users/stefmolin/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/stefmolin/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/stefmolin/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/stefmolin/subscriptions',
#    'organizations_url': 'https://api.github.com/users/stefmolin/orgs',
#    'repos_url': 'https://api.github.com/users/stefmolin/repos',
#    'events_url': 'https://api.github.com/users/stefmolin/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/stefmolin/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-12-31T22:40:04Z',
#   'updated_at': '2021-12-31T22:40:04Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the master branch of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\n\r\ndf = pd.DataFrame(\r\n    {'A': [4, 2, 1, 2, 5, 2]}, index=pd.RangeIndex(6, name='B')\r\n)\r\n\r\ndf.plot(kind='barh', xlabel='x', ylabel='y')\n```\n\n\n### Issue Description\n\nWith `bar` plots, we can pass `xlabel` and `ylabel` to `plot()` and have those values set as the x- and y-axis labels (overriding any defaults). However, if you try this with a `barh` plot both `xlabel` and `ylabel` update the y-axis label, and the only way to update the x-axis label is after the fact with `ax.set_xlabel()`. Here's the result for the code above:\r\n\r\n![image](https://user-images.githubusercontent.com/24376333/147840408-7c71efed-5937-4c2b-984c-73d6a1f89faf.png)\r\n\n\n### Expected Behavior\n\nWith the code provided above, I would expect this:\r\n\r\n![image](https://user-images.githubusercontent.com/24376333/147840422-2da4e1dd-11a2-4aa6-b6ed-38ef99dfc590.png)\r\n\r\n\r\nIn addition, providing only `xlabel` should label the x-axis only (currently, this updates the y-axis label, which is confusing).\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 945c9ed766a61c7d2c0a7cbb251b6edebf9cb7d5\r\npython           : 3.9.6.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 19.6.0\r\nVersion          : Darwin Kernel Version 19.6.0: Thu Sep 16 20:58:47 PDT 2021; root:xnu-6153.141.40.1~1/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.3.4\r\nnumpy            : 1.20.3\r\npytz             : 2021.1\r\ndateutil         : 2.8.2\r\npip              : 21.2.4\r\nsetuptools       : 52.0.0.post20210125\r\nCython           : 0.29.25\r\npytest           : 6.2.5\r\nhypothesis       : 6.29.3\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.6.3\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.0.2\r\nIPython          : 7.29.0\r\npandas_datareader: 0.10.0\r\nbs4              : None\r\nbottleneck       : 1.3.2\r\nfsspec           : None\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : 3.4.2\r\nnumexpr          : 2.7.3\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.7.1\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nnumba            : None\r\n\r\n</details>\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45144/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45144/timeline',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45142',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45142/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45142/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45142/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/45142',
#   'id': 1091658946,
#   'node_id': 'PR_kwDOAA0YD84wbOTT',
#   'number': 45142,
#   'title': 'BUG: Series(floatlike, dtype=intlike) inconsistent with non-ndarray data',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-12-31T20:00:20Z',
#   'updated_at': '2022-01-01T04:45:21Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/45142',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/45142',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/45142.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/45142.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx\r\n- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit) for how to run them\r\n- [x] whatsnew entry\r\n\r\nxref #40110.  That issue contains a lot of moving parts, need to see what it will take to actually close.\r\n\r\nCan refactor to de-duplicate in a follow-up.  (may be easier after deprecations are enforced)',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45142/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/45142/timeline',
#   'performed_via_github_app': None}]
