# %% [markdown]
# # 0625_과제

# %% [markdown]
# Q. 문자열 리스트 states를 정형화하여 아래와 같이 출력하세요
# states = ['   Alabama ', 'Georgia!', 'Georgia', 'georgia', 'FlOrIda','south   carolina##', 'West virginia?']
#
# [출력]
# ['Alabama',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Florida',
#  'South   Carolina',
#  'West Virginia']

# %%
states = [' Alabama ', 'Georgia!', 'Georgia', 'georgia', 'FlOrIda','south carolina##', 'West virginia?']

list(map(lambda x: x.strip(' !#?').title(), states))
# Out:
# ['Alabama',
#  'Georgia',
#  'Georgia',
#  'Georgia',
#  'Florida',
#  'South Carolina',
#  'West Virginia']

# %% [markdown]
# Q. 1000명에 대하여 아래와 같이 출력하세요
# bmi = round(int(weight) / ((int(height) / 100) ** 2),2)
# 이름 :라바
# 몸무게: 80
# 키: 146
# BMI: 37.53049352598987
# 결과: 과체중
#
# BMI Categories:
# Underweight = <18.5
# Normal weight = 18.5–24.9
# Overweight = 25–29.9
# Obesity = BMI of 30 or greater'

# %%
import random

hanguls = '가나다라마바사아자차카타파하'
with open('info.txt','w') as f:
    for i in range(1, 1001):
        name = random.choice(hanguls) + random.choice(hanguls)
        height = random.randrange(140,200)
        weight = random.randrange(40,100)
        f.write('{},{},{}\n'.format(name, height, weight))

# %%
with open('info.txt','r') as f:
    lines = f.readlines()
    for line in lines:
        name, weight, height = line.split(',')
        bmi = round(int(weight)/((int(height)/100)**2),2)
        if bmi <= 18.5:
            result = 'Underweight'
        elif 18.5 < bmi <= 24.9:
            result = 'Nomalweight'
        elif 25.0 <= bmi <= 29.9:
            result = 'Overweight'
        else:
            result = 'Obesity'
        print('이름 : {}\n몸무게 : {}\n키 : {}BMI : {}\n결과 : {}\n'.format(
        name, weight, height, bmi, result))
# Out:
# 이름 : 나아
# 몸무게 : 193
# 키 : 80
# BMI : 301.56
# 결과 : Obesity
#
# 이름 : 하마
# 몸무게 : 190
# 키 : 95
# BMI : 210.53
# 결과 : Obesity
#
# 이름 : 사하
# 몸무게 : 143
# 키 : 74
# BMI : 261.14
# 결과 : Obesity
#
# 이름 : 하라
# 몸무게 : 182
# 키 : 52
# BMI : 673.08
# 결과 : Obesity
#
# 이름 : 바카
# 몸무게 : 152
# 키 : 92
# BMI : 179.58
# 결과 : Obesity
#
# 이름 : 바라
# 몸무게 : 146
# 키 : 93
# BMI : 168.81
# 결과 : Obesity
#
# 이름 : 차자
# 몸무게 : 196
# 키 : 72
# BMI : 378.09
# 결과 : Obesity
#
# 이름 : 카하
# 몸무게 : 155
# 키 : 40
# BMI : 968.75
# 결과 : Obesity
#
# 이름 : 가바
# 몸무게 : 179
# 키 : 56
# BMI : 570.79
# 결과 : Obesity
#
# 이름 : 파자
# 몸무게 : 197
# 키 : 95
# BMI : 218.28
# 결과 : Obesity
#
# 이름 : 다가
# 몸무게 : 192
# 키 : 48
# BMI : 833.33
# 결과 : Obesity
#
# 이름 : 바카
# 몸무게 : 150
# 키 : 87
# BMI : 198.18
# 결과 : Obesity
#
# 이름 : 하파
# 몸무게 : 174
# 키 : 46
# BMI : 822.31
# 결과 : Obesity
#
# 이름 : 나차
# 몸무게 : 176
# 키 : 57
# BMI : 541.71
# 결과 : Obesity
#
# 이름 : 자바
# 몸무게 : 155
# 키 : 42
# BMI : 878.68
# 결과 : Obesity
#
# 이름 : 마하
# 몸무게 : 157
# 키 : 98
# BMI : 163.47
# ...

# %% [markdown]
# Q. 사칙연산 기능을 포함하는 모듈 cal4.py 을 작성 후 임포트해서 사칙연산을수행하세요.

# %%
with open('cal4.py','w') as f:
    f.write('''
def cal(choice, *args):
    if choice == '+':
        result = 0
        for i in args:
            result += i
        print(result)
    elif choice == '*':
        result = 1
        for i in args:
            result *= i
        print(result)
    elif choice == '-':
        for n,i in enumerate(args):
            if n == 0:
                result = i
            else:
                result -= i
        print(result)
    elif choice == '/':
        try:
            for n,i in enumerate(args):
                if n == 0:
                    result = i
                else:
                    result /= i
            print(result)
        except:
            print('다시 입력해주세요.')
    else:
        print('다시 입력해주세요.')
''')

# %% [markdown]
# 만든 후 !python cal4.py  실행

# %%
from cal4 import cal

cal('/',10,5,2)
cal('/',10,5,0)
cal('+',10,5,2)
# Out:
# 1.0
# 다시 입력해주세요.
# 17
