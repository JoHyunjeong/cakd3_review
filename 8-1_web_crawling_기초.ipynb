# %% [markdown]
# # 7/5

# %%
text = "<k-digital training 3기>"
text1 = 'abc abc abc'
print(text[0])
print(text[-1])
print(text.capitalize()) ### 첫 단어의 첫 번째 글자 대문자
print(text1.capitalize())
print(text.title()) ### 모든 단어의 첫 번째 글자는 대문자
print(text1.title())
print(text.upper()) ### 다 대문자로 바꿈
print(text1.upper())
# Out:
# <
# >
# <k-digital training 3기>
# Abc abc abc
# <K-Digital Training 3기>
# Abc Abc Abc
# <K-DIGITAL TRAINING 3기>
# ABC ABC ABC

# %%
# Q. 다음을 출력하세요
# <k-digital traning 3기>;
# <k-digital traning 3기>    ;
#    <k-digital traning 3기>;
text1 = "  <k-digital training 3기>    "
text2 = ';'

print(text1.strip() + text2)
print(text1.lstrip() + text2)
print(text1.rstrip() + text2)
# Out:
# <k-digital training 3기>;
# <k-digital training 3기>    ;
#   <k-digital training 3기>;

# %%
# Q. 다음을 출력하세요.
# <div>k-digital training 3기</title>
# <div>k-digital training 3기</div>
text = "<title>k-digital training 3기</title>"

print(text.replace('<title>', '<div>'))
print(text.replace('title', 'div'))
# Out:
# <div>k-digital training 3기</title>
# <div>k-digital training 3기</div>

# %%
# Q. <head>안녕하세요</head> 출력하세요.
import re
text = ('111<head>안녕하세요</head>22')  ## <  > 열어주는거, </  > 닫아주는거

body = re.search('<head>.+</head>',text)
print(body.group())
# Out:
# <head>안녕하세요</head>

# %%
import re
text = ('111<head>안녕하세요</head>22')
body = (re.search("[가-힣]+",text))
print(body.group())
# Out:
# 안녕하세요

# %%
import requests # 파이썬에서 HTTP 웹 요청을 보내는 모듈
URL = 'https://naver.com'
response = requests.get(URL)
print(response.text)
# Out:
# <!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 
# ...

# %%
# Q. "네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" 출력하세요
text = '''<meta name="description" 
content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>'''

import re
body = re.search('([가-힣]+\s?)+',text)
print(body.group())
# Out:
# 네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요

# %%
# 다른 풀이
text = '''<meta name="description" 
content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>'''

body = re.search('[가-힣].+[가-힣]',text)
print(body.group())

# 다른 풀이
p = re.search('[가-힣]+.+[\w]',text)
print(p.group())

# 다른 풀이
print (" ".join(re.findall("[가-힣]+",text)))

# 다른 풀이
body = re.search('([가-힣]+ *)+',text)
print(body.group())
# Out:
# 네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요
# 네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요
# 네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요
# 네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요

# %%
# Q. k-digital training 3기 를 출력하세요
import re
text = '<title>k-digital training 3기</title>'

body = (re.search("k.+[가-힣]",text))
print(body.group())
# Out:
# k-digital training 3기

# %%
import re
text = '<title>k-digital training 3기</title>'

text = re.sub("<title>","",text)
text = re.sub("</title>","",text)
print(text)
# Out:
# k-digital training 3기

# %%
import re
text = '<title>k-digital training 3기</title>'
text = re.sub('<.+?>','',text)
print(text)
# Out:
# k-digital training 3기

# %%
# Q. 'k-digital training 3기'을 출력하세요.

text = '''<head> 안녕하세요... <title>k-digital training 3기</title>
반갑습니다... </head>'''

import re

body = re.search('<title.*/title>',text)
body = body.group()
body = re.sub('<.+?>','',body)
print(body)
# Out:
# k-digital training 3기

# %%
text = '''<head> 안녕하세요... <title>k-digital training 3기</title>
반갑습니다... </head>'''

a = re.sub('<.+?>','',text)
b = re.sub('([가-힣]+...)','',a)
print(b)
# Out:
#   k-digital training 3기

# %% [markdown]
# requests 모듈 : pip install requests 명령어로 설치, anaconda를 설치하면 기본 설치
# - import requests로 모듈 호출 후 사용
#
#
# (아나콘다 설치했지만, 가상환경 만들어서 사용했으므로 설치해야함!
# conda list로 확인 후 있으면 pass)

# %%
# !conda list
# Out:
# # packages in environment at /Users/hyunjeongjo/opt/anaconda3:
# #
# # Name                    Version                   Build  Channel
# _py-xgboost-mutex         2.0                       cpu_0    anaconda
# anaconda-client           1.9.0            py38hecd8cb5_0
# anaconda-navigator        2.1.1                    py38_0
# appnope                   0.1.2           py38hecd8cb5_1001
# argon2-cffi               20.1.0           py38h9ed2024_1
# async_generator           1.10               pyhd3eb1b0_0
# attrs                     21.2.0             pyhd3eb1b0_0
# backcall                  0.2.0              pyhd3eb1b0_0
# backports                 1.0                pyhd3eb1b0_2
# backports.functools_lru_cache 1.6.4              pyhd3eb1b0_0
# backports.tempfile        1.0                pyhd3eb1b0_1
# backports.weakref         1.0.post1                  py_1
# beautifulsoup4            4.10.0             pyh06a4308_0
# blas                      1.0                         mkl
# ...

# %% [markdown]
# 인터넷창에 "view-source:https://www.naver.com/" 입력하면 코드 나옴
# 또는 F12 누르면 뜸
# 또는 Ctrl+i

# %%
import requests
URL = 'https://www.naver.com'
response = requests.get(URL) ### 이 사이트 요청해서 제대로 받을 수 있는지 확인
print(response.status_code) ### 4로 시작하면 없는거, 2로 시작하면 가능(정상)
print(response.text)
# Out:
# 200
#
# ...

# %%
import requests

html_data = response.text ### 위 데이터를 텍스트로!
print(html_data.find('네이버'))
print(html_data[365:368]) ### 인덱스로 '네이버' 뽑아내기
# Out:
# 365
# 네이버

# %%
# Q. '네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요'을 출력하세요.

html_data = response.text
print(html_data.find('네이버 메인에서'))
print(html_data.find('보세요'))
print(html_data[365:397])
# Out:
# 365
# 394
# 네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요

# %%
# Q. 위 문제를 정규표현식으로 출력하세요.
import re
html_data = response.text
# print(html_data)
a = re.search('([가-힣]+\s?)+',html_data)
print(a.group())
# Out:
# 네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요

# %%
content = html_data.split('<meta property=')[1]
print(content)
content = re.search('네이버',content)
print(content.group())
# Out:
# "og:title" content="네이버">
# 네이버

# %%
# get 메소드에 params 인자를 넣어 함께 get 요청(파라미터 : query)
import requests
URL = 'https://search.naver.com/search.naver'
params = {'query':'aa'}
response1 = requests.get(URL, params=params)
# print(response.status_code)
response.text
# Out:
# '\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네
# ...

# %%
import requests

URL = 'https://www.naver.com'
response = requests.get(URL)
content = response.text
body = re.search('<h3.*/h3>',content)
body.group()
text = re.search('[가-힣]+',body.group())
print(text.group())
# Out:
# 공지사항

# %%
# Q. 'https://datalab.naver.com' 에서 원피스를 출력하세요.

import requests

URL = 'https://datalab.naver.com'
response = requests.get(URL)
content = response.text
body = re.search('원피스', content)
print(body.group())
# Out:
# 원피스

# %%
# Q. URL = 'http://naver.com'에서 split()함수와 정규표현식을 이용하여
# ['메일', '카페', '블로그', '지식in', '쇼핑']을 출력하세요.

URL = 'http://naver.com'
response = requests.get(URL)
html_data = response.text
# print(html_data)
li = []
for i in range(5):
    result = html_data.split('<li class="nav_item">')[i+1]
#     print(result)
    word = re.sub('<.*?>','',result)
    word = re.sub(r'\n','',word)
    li.append(word)
print(li)
# Out:
# ['메일', '카페', '블로그', '지식iN', '쇼핑']

# %% [markdown]
# urllib 모듈이란: 파이썬의 표준 모듈로써 URL을 다루기 위한 모듈 패키지
# - 설치가 필요하지 않고 import urllib로 활용
# - requests 모듈과 마찬가지로 URL과 관련된 여러가지 기능들을 제공 하위모듈
# - request : URL을 열고 읽는 모듈(HTTP요청)
# - error : request 모듈에서 발생하는 에러들을 포함하는 모듈
# - parse : URL을 파싱하는 모듈(URL 해석 및 조작)
# - robots.txt 파일을 파싱하는 모듈

# %%
import urllib
URL = 'https://www.naver.com'
request = urllib.request.Request(URL) # 객체 가져옴
print(request)
print(request.full_url) # URL 뽑아냄
print(request.type)
print(request.host)
# Out:
# ...
# https://www.naver.com
# https
# www.naver.com

# %%
import urllib
URL = 'https://www.naver.com'
response = urllib.request.urlopen(URL)
response.read().decode('utf-8')
# Out:
# '\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네
# ...

# %%
import urllib
URL = 'https://www.naver.com'
response = urllib.request.urlopen(URL)
byte_data = response.read(500) ### 괄호 안에 넣은 숫자만큼 글자 수 불러옴. 빈칸 다 나옴
text_data = byte_data.decode('utf-8')
print(text_data)
# Out:
# <!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <m

# %%
# urllib.request.urlretrieve() : 웹상의 이미지 저장
import urllib.request
img_src = 'https://homepages.cae.wisc.edu/~ece533/images/tulips.png'
new_name = 'img.png'
urllib.request.urlretrieve(img_src,new_name)
# Out:
# ('img.png', <http.client.HTTPMessage at 0x7fb8c86d3e50>)

# %%
# 단순한 패턴을 읽을 때는 복잡한 정규표현식 보다는 간단한 parse 모듈을 사용
# urllib.parse : url을 6개로 분리하여 반환

import urllib
parse = urllib.parse.urlparse('https://section.blog.naver.com/Search/Post.naver?pageNo=1&rangeType=ALL&orderBy=sim&keyword=ai'
)
print(parse)
print(parse[0])
print(parse[5])
print(parse[:])
print(parse.query)
# Out:
# ParseResult(scheme='https', netloc='section.blog.naver.com', path='/Search/Post.naver', params='', query='pageNo=1&rangeType=ALL&orderBy=sim&keyword=ai', fragment='')
# https
#
# ('https', 'section.blog.naver.com', '/Search/Post.naver', '', 'pageNo=1&rangeType=ALL&orderBy=sim&keyword=ai', '')
# pageNo=1&rangeType=ALL&orderBy=sim&keyword=ai

# %%
# 튜플(변경 불가능)로 반환되기 때문에 리스트(변경 가능)로 변경하여 활용
import urllib
parse = urllib.parse.urlparse('https://blog.naver.com/koreatech91;a=1?b=2#b')
print(parse)

parse = list(parse)
parse[1] = 'blog.daum.net' ### 리스트로 바꾸지 않은 경우 이렇게 하면 에러남. 튜플형식이라 수정 불가
print(parse)
# Out:
# ParseResult(scheme='https', netloc='blog.naver.com', path='/koreatech91', params='a=1', query='b=2', fragment='b')
# ['https', 'blog.daum.net', '/koreatech91', 'a=1', 'b=2', 'b']
